# %%
import os
print(os.getcwd())
os.chdir("D:")
print(os.getcwd())
# Out:
# C:\Users\LJENG\A1_28_T3
# D:\

# %%
import os
os.mkdir("python1")

# %%
f = open("new1.txt","w")
f.write("Hello")
f.close()

# %%
os.chdir("D:\\python1")
os.getcwd()
# Out:
# 'D:\\python1'

# %%
os.mkdir("New")
f = open("file.txt","w")
f.write("python")
f.close()

# %%
os.chdir("..")
os.getcwd()
# Out:
# 'D:\\'

# %%
os.remove("D:\\new1.txt")
os.remove("D:\\python1\\file.txt")

# %%
os.rmdir("D:\\python1\\New")
os.rmdir("D:\\python1")

# %%
print(os.listdir("D:"))
print(123)
os.listdir("C:")
# Out:
# ['$RECYCLE.BIN', '24002171210162', 'Diya', 'fsd_t3', 'LskLock.tmp', 'mydir', 'mymodule.py', 'mymodule.txt', 'Newdirectory', 'System Volume Information', 'T3_python']
# 123
# ['$Recycle.Bin',
#  '$WinREAgent',
#  'Config.Msi',
#  'DEMO',
#  'Documents and Settings',
#  'DumpStack.log.tmp',
#  'hiberfil.sys',
#  'inetpub',
#  'Insight Files',
#  'Intel',
#  'msdia80.dll',
#  'MSOCache',
#  'oraclexe',
#  'pagefile.sys',
#  'PerfLogs',
#  'Program Files',
#  'Program Files (x86)',
#  'ProgramData',
#  'Recovery',
#  'RESULT',
#  'swapfile.sys',
#  'System Volume Information',
#  'TempVerification',
#  'TurboC++',
#  'Users',
#  'Windows',
#  'xampp']

# %%
import datetime as dt
print(dt.date(2025,11,20))
print(dt.date.today())
print(dt.time(12,12,12))
print(dt.time(12,12,12,121212))
print(dt.datetime(2025,11,10))
print(dt.datetime(2025,11,10,9,8))
print(dt.datetime(2025,11,10,9,8,7,654321))
print(dt.datetime.now())
# Out:
# 2025-11-20
# 2025-12-01
# 12:12:12
# 12:12:12.121212
# 2025-11-10 00:00:00
# 2025-11-10 09:08:00
# 2025-11-10 09:08:07.654321
# 2025-12-01 12:06:35.963887

# %%
# %%writefile first_word.py
def word(s):
    return s.split()[0]
# Out:
# Writing first_word.py

# %%
import first_word as f
user = input("Enter string : ")
print(f.word(user))
# Out:
# Enter string : This is the end
# This

# %%
Exception	Description
IndexError	When the wrong index of a list is retrieved.
AssertionError	It occurs when the assert statement fails
AttributeError	It occurs when an attribute assignment is failed.
ImportError	It occurs when an imported module is not found.
KeyError	It occurs when the key of the dictionary is not found.
NameError	It occurs when the variable is not defined.
MemoryError	It occurs when a program runs out of memory.
TypeError	It occurs when a function and operation are applied in an incorrect type

# %%
try:
    print("try")
    print(x)
    print(2//0)
except:
    print("error")

# %%
try:
    print("try")
    print(x)
    print(2//0)
except Exception as e:
    print(e)
# Out:
# try
# name 'x' is not defined

# %%
try:
    a=5
    b=6
    print(a+b)
    l=[1,2,3]
    #print(int("A")) #ValueError
    #l.extend(20) #TypeError
    #print(c) #NameError
    #print(4//0) #ZeroDivisionError
except ValueError:
    print("Value error")
except TypeError:    
    print("Type error")
except NameError:
    print("Name error")
except:
    print("Other error")
else:
    print("if this prints then except didn't execute")
finally:
    print("this will be printed at last always")
# Out:
# 11
# if this prints then except didn't execute
# this will be printed at last always

# %%
def fun(a):
    try:
        print(10)
        return 1
    except:
        return 2
    else:
        return 3
    finally:
        return 4
print(fun("A"))
# Out:
# 10
# 4

# %%
def fun(a):
    try:
        print(10)
        return 1
    except:
        return 2
    else:
        return 3
print(fun("B"))
# Out:
# 10
# 1

# %%
def fun(a):
    try:
        print(10)
        return 1
    except:
        return 2
    finally:
        print(20)
print(fun("C"))
# Out:
# 10
# 20
# 1

# %%
try:
    print(1)
finally:
    print(2)
# Out:
# 1
# 2

# %%
class m:
    x = 10
    def mm(a):
        return a*a
print(m.x, m.mm(m.x))
# Out:
# 10 100

# %%
class Name:
    n = 0
    def print_name(self):
        self.n = "ABC"
        return self.n
    def random(self):
        self.n = 10
        return self.n

# %%
N = Name()
print(N.print_name())
print(N.random())
# Out:
# ABC
# 10
