# %%
# Write a program to compare two text files. If they are different, give the line and column numbers in the files where the
# first difference occurs.
# Example:
# File 1: python1.txt
# Friends are crazy, Friends are naughty !
# Friends are honest, Friends are best !
# Friends are like keygen, friends are like license key !
# new We are nothing without friends, Life is not possible without friends !
# File 2: python2.txt
# Friends are crazy, Friends are naughty !
# Friends 6re honest, Friends are best !
# Friends are like keygen, friends are like license key !
# new We are nothing without friends, Life is not possible without friends !
# Output:
# line number 2 colNo. 9

f1 = open("f1.txt")
f2 = open("f2.txt")

file1 = f1.readlines()
file2 = f2.readlines()

for i,j in enumerate(file1):
    if j != file2[i]:
        for k,l in enumerate(j):
            if l != file2[i][k]:
                print(f"Line number {i+1} and column {k+1}")
                break
        break

f1.close()
f2.close()
# Out:
# Line number 2 and column 9

# %%
# %%writefile f1.txt
# Friends are crazy, Friends are naughty !
# Friends are honest, Friends are best !
# Friends are like keygen, friends are like license key !
# new We are nothing without friends, Life is not possible without friends !
# Out:
# Writing f1.txt

# %%
# %%writefile f2.txt
# Friends are crazy, Friends are naughty !
# Friends 6re honest, Friends are best !
# Friends are like keygen, friends are like license key !
# new We are nothing without friends, Life is not possible without friends !
# Out:
# Writing f2.txt

# %%
# Write a python program to read through the mbox-short.txt and figure out who has
# sent the greatest number of mail messages. The program looks for 'From ' lines and
# takes the second word of those lines as the person who sent the mail. The program
# creates a Python dictionary that maps the sender's mail address to a count of the
# number of times they appear in the file. After the dictionary is produced, the program reads through the dictionary to
# identify the sender with the maximum count (the most prolific sender).
# Expected Output:
# {'stephen.marquard@uct.ac.za': 2, 'louis@media.berkeley.edu': 3, 'zqian@umich.edu': 4, 'rjlowe@iupui.edu': 2,
# 'cwen@iupui.edu': 5, 'gsilver@umich.edu': 3, 'wagnermr@iupui.edu': 1, 'antranig@caret.cam.ac.uk': 1,
# 'gopal.ramasammycook@gmail.com': 1, 'david.horwitz@uct.ac.za': 4, 'ray@media.berkeley.edu': 1}
# cwen@iupui.edu 5

f1 = open("mbox-short.txt")
name = ""
l1 = []
for i in f1:
    l = i.split()
    if len(l)>0 and l[0]=='From':
        name = l[1]
        l1.append(name)
        
l2 = []
for i in l1:
    c = l1.count(i)
    l2.append(c)

t1 = tuple(l1)
t2 = tuple(l2)
d = dict(zip(t1,t2))
print(d,"\n")

m = 0
n = ""
for i in d:
    if d[i]>m:
        n=i
        m=d[i]
print(n)
# Out:
# {'stephen.marquard@uct.ac.za': 2, 'louis@media.berkeley.edu': 3, 'zqian@umich.edu': 4, 'rjlowe@iupui.edu': 2, 'cwen@iupui.edu': 5, 'gsilver@umich.edu': 3, 'wagnermr@iupui.edu': 1, 'antranig@caret.cam.ac.uk': 1, 'gopal.ramasammycook@gmail.com': 1, 'david.horwitz@uct.ac.za': 4, 'ray@media.berkeley.edu': 1}
#
# cwen@iupui.edu

# %%
# %%writefile f3.txt
# Apple is a healthy fruit
# Greenapple is sweet & tasty
# Orange and bananas are good for health
# Fruits are good source of vitamins
# Out:
# Writing f3.txt

# %%
# WAP where using a file which have multiple statements find all the words from the file that can be made from all the 
# characters of given users substring

s = input("Enter the sub-string : ")
f = open("f3.txt")

l1 = list(s)
for i in f:
    l2 = i.split()
    for j in l2:
        count = 0
        l3 = list(j)
        for k in l3:
            if k in l1:
                count+=1     
        if count>=len(l1):
            print(j)
# Out:
# Enter the sub-string : san
# Oranges
# bananas
# vitamins

# %%
# %%writefile cal.py
def add(a,b):
    return a+b
def div(a,b):
    return a/b
def mul(a,b):
    return a*b
# Out:
# Writing cal.py

# %%
import cal
x = cal.add(5,7)
print(x)
y = cal.mul(5,7)
print(y)
# Out:
# 12
# 35

# %%
from cal import *
x = add(5,7)
print(x)
# Out:
# 12

# %%
from cal import div
x = div(2,3)
print(x)
# Out:
# 0.6666666666666666

# %%
import cal as c
x = mul(2,4)
print(x)
# Out:
# 8

# %%
from cal import div as d, mul as m
x = d(3,5)
print(x)
y = m(5,8)
print(y)
# Out:
# 0.6
# 40

# %%
# abc1 folder --> cal module
# import abc1.cal

# d: --> abc1 --> cal module
# Restart kernal
# import sys
# sys.path.append("D:")
# print(sys.path)
# from abc1 import cal

# %%
import os

print(os.getcwd())
os.chdir("D:")
print(os.getcwd())
os.mkdir("python")
# Out:
# D:\
# D:\
