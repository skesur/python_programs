# %%
# Stacks and Queues. Write a class SQ that defines a data structure that can behave as both a queue(FIFO) or a stack(LIFO),
# There are five methods that should be implemented:
# 1.make a constructor with a valid parameter
# 2.shift() returns the first element and removes it from the list. Also, use the custom(raise) excepƟon in this method.
# 3.unshift() "pushes" a new element to the front or head of the list
# 4.push() adds a new element to the end of a list
# 5.pop() returns the last element and removes it from the list
# 6.remove() returns the maximum element of the list and removes it from the list.
# 7.Create the object and call all methods of the SQ class

class SQ:
    def __init__(self):
        self.L=eval(input("Enter List: "))
    def shift(self):
        try:
            if len(self.L)>0:
                x=self.L.pop(0)
                return x
            else:
                raise Exception("List is empty")
        except Exception as e:
            print(e)
    def unshift(self,a):
        self.L.insert(0,a)
    def push(self,a):
        self.L.append(a)
        return self.L 
    def pop(self):
        try:
            if len(self.L)>0:
                x=self.L.pop()
                return x
            else:
                raise Exception("List is empty")
        except Exception as e:
            print(e)
    def remove(self):
        x=max(self.L)
        self.L.remove(x)
        return x

# %%
# Write a program to build a simple Student Management System using Object Oriented Programming in Python which can
# perform the following operations:
# accept-This method takes details from the user like name, roll number, and marks for two different subjects.
# display-This method displays the details of every student.
# search-This method searches for a particular student from the list of students. This method will ask the user for roll
# number and then search according to the roll number
# delete-This method deletes the record of a particular student with a matching roll number.
# update-This method updates the roll number of the student. This method will ask for the old roll number and new roll
# number. It will replace the old roll number with a new roll number.
# The following instructions need to be considered while making a program.
# 1.Give class name as Student
# 2.Include methods name as accept, display, search, delete and update. (1 mark for each correct method to be formed).
# 3.Also form constructor with __init__ () method (2 marks for forming constructor).
# 4.2 marks for correct object prepared like aŌer deleƟon of one roll no of student it should update the list with new roll
# no. and should display it

class StudentManagement:
    students = []
    def __init__(self,n,r,m1,m2):
        self.name=n
        self.rollno=r
        self.marks1=m1
        self.marks2=m2
        StudentManagement.students.append(self)
    def accept(self):
        n=input("Enter Name : ")
        r=int(input("Enter Rollno. : "))
        m1=int(input("Enter marks of 1st subject : "))
        m2=int(input("Enter marks of 2nd subject : "))
        StudentManagement(n,r,m1,m2)
        print("Student with name ",n," added successfully")
    def display(self):
        for i in StudentManagement.students:
            print(f"name: {i.name}, rollno: {i.rollno}, marks1: {i.marks1}, marks2: {i.marks2}")
    def search(self,r):
        for i in StudentManagement.students:
            if i.rollno==r:
                print(f"name: {i.name}, rollno: {i.rollno}, marks1: {i.marks1}, marks2: {i.marks2}")
                return
            if i.rollno!=r and i==StudentManagement.students[-1]:
                print(f"Student with rollno. {r} not found")
    def delete(self,r):
        for i in StudentManagement.students:
            if i.rollno==r:
                print(f"Student record deleted with rollno. {r}")
                StudentManagement.students.remove(i)
                return
            if i.rollno!=r and i==StudentManagement.students[-1]:
                print(f"Student with rollno. {r} not found")  
    def update(self,r):
        for i in StudentManagement.students:
            if i.rollno==r:
                i.rollno=int(input("Enter Rollno. : "))
                return
            if i.rollno!=r and i==StudentManagement.students[-1]:
                print(f"Student with rollno. {r} not found") 
s = StudentManagement("Abc",1,24,23)
s.accept()
s.display()
r=int(input("Enter the roll no to search student : "))
s.search(r)
r=int(input("Enter the roll no to delete student : "))
s.delete(r)
s.display()
r=int(input("Enter the roll no to update student : "))
s.update(r)
s.display()
# Out:
# Enter Name : rol
# Enter Rollno. : 3
# Enter marks of 1st subject : 20
# Enter marks of 2nd subject : 20
# Student with name  rol  added successfully
# name: Abc, rollno: 1, marks1: 24, marks2: 23
# name: rol, rollno: 3, marks1: 20, marks2: 20
# Enter the roll no to search student : 1
# name: Abc, rollno: 1, marks1: 24, marks2: 23
# Enter the roll no to delete student : 3
# Student record deleted with rollno. 3
# name: Abc, rollno: 1, marks1: 24, marks2: 23
# Enter the roll no to update student : 1
# Enter Rollno. : 2
# name: Abc, rollno: 2, marks1: 24, marks2: 23

# %%
# Write a python program that has a class Point with attributes as the x and y co-ordinates.
# 1.Add a method ‘distance from origin’ to class Point which returns the distance of the given point from origin. The
# equation is
# 2.Add a method ‘translate’ to class Point, which returns a new posiƟon of point after translation
# 3.Add a method ‘reflect_x’ to class Point, which returns a new point which is the reflecƟon of the point about the x-axis
# 4.Add a method ‘distance’ to return distance of the given point with respect to the other point. The formula for 
# calculating distance between A(x1,y1) and B(x2,y2) is

class Point:
    def __init__(self,x,y):
        self.x=x
        self.y=y
    def origin_dist(self):
        d=(self.x**2+self.y**2)**(0.5)
        return d
    def translate(self,dx,dy):
        new_x=self.x+dx
        new_y=self.y+dy
        return new_x,new_y
    def reflect_x(self):
        return self.x,-self.y
    def distance(self,other):
        d=((self.x-other.x)**2+(self.y-other.y)**2)**(0.5)
        return d
p1=Point(1,2)
print(p1.origin_dist())
print(p1.translate(1,1))
print(p1.reflect_x())
p2=Point(3,4)
print(p1.distance(p2))
# Out:
# 2.23606797749979
# (2, 3)
# (1, -2)
# 2.8284271247461903

# %%
# You own a pizzeria named Olly’s Pizzas and want to create a Python program to handle the customers and revenue.
# Create the following classes with the following methods:
# Class Pizza containing
# 1.init method: to iniƟalize the size (small, medium, large), toppings (corn, tomato, onion, capsicum, mushroom, olives,
# broccoli), cheese (mozzarella, feta, cheddar). Note: One pizza can have only one size but many toppings and cheese. (1.5
# marks)
# Throw custom exceptions if the selects toppings or cheese not available in lists given above. (1 mark)
# 2.price method: to calculate the prize of the pizza in the following way:
# small = 50, medium = 100, large = 200
# Each topping costs 20 rupees extra, except broccoli, olives and mushroom, which are exotic and so cost 50 rupees each.
# Each type of cheese costs an extra 50 rupees. (1.5 marks)
# Class Order containing
# 1.init method: to iniƟalize the name, customerid of the customer who placed the order (0.5 marks)
# 2.order method: to allow the customer to select pizzas with choice of toppings and cheese (1 mark)
# 3.bill method: to generate details about each pizza ordered by the customer and the total cost of the order. (2 marks)
# *Note: A customer can get multiple pizzas in one order.
# 1.5 marks for creating appropriate objects of these classes and writing correct output.

class Olly:
    s1=""
    t1=[]
    c1=[]
    size=["small","medium","large"]
    s_p=[50,100,200]
    toppings=["corn", "tomato", "onion", "capsicum", "mushroom", "olives","brocolli"]
    t_p=20
    cheese=["mozzarella", "feta", "cheddar"]
    c_p=50
    def __init__(self,s,t,c):
        if s in self.size:
            self.s1=s
        else:
            raise Exception("Select size is not available")
        for i in t:
            if i in self.toppings:
                self.t1.append(i)
            else:
                raise Exception("Select topping is not available")
        for i in c:
            if i in self.cheese:
                self.c1.append(i)
            else:
                raise Exception("Select cheese is not available")
        print(self.s1,self.t1,self.c1)        
    def price(self):
        self.price=0
        p=0
        if self.size=="small":
            self.price+=50
        elif self.size=="medium":
            self.price+=100 
        elif self.size=="large":
            self.price+=150    
        for i in self.t1:
            self.price+=self.t_p
        for i in self.c1:
            self.price+=self.c_p
        return self.price

o = Olly("small",["corn", "tomato"],["mozzarella", "feta"])  
print(o.price())
# Out:
# small ['corn', 'tomato'] ['mozzarella', 'feta']
# 140
